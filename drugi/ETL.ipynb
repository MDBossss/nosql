# %% [markdown]
# <img src="vua.png">

# %% [markdown]
# ### Učitavanje podataka iz datoteke i prikaz prva tri zapisa za svaku kategoriju irisa

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib as plt

path='iris.csv'
df = pd.read_csv(path, sep=',')

df.groupby('iris').head(3)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth             iris
# 0            5.1         3.5          1.4         0.2      Iris-setosa
# 1            4.9         3.0          1.4         0.2      Iris-setosa
# 2            4.7         3.2          1.3         0.2      Iris-setosa
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 51           6.4         3.2          4.5         1.5  Iris-versicolor
# 52           6.9         3.1          4.9         1.5  Iris-versicolor
# 100          6.3         3.3          6.0         2.5   Iris-virginica
# 101          5.8         2.7          5.1         1.9   Iris-virginica
# 102          7.1         3.0          5.9         2.1   Iris-virginica

# %% [markdown]
# Pogledaj prethodnu vježbu i prikaži dokumente u koji se nalaze u mapi vježbe.

# %%
! ls
# Out:
# ETL.html  ETL.ipynb  iris.csv  iris.xls  iris.xlsx

# %% [markdown]
# Pogledaj prethodnu vježbu i prikaži prve retke iz dokumenta iris.csv.

# %%
!

# %% [markdown]
# ### Deskriptivna statistika
# Napravi osnovnu deskriptivnu analizu (describe).

# %%
df.describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  149.000000   149.000000  150.000000
# mean      5.843333    3.055034     3.751678    1.198667
# std       0.828066    0.434871     1.768287    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.300000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# Korištenjem *groupby* napravi prikaz srednje vrijednosti po vrstama irisa.

# %%
df.groupby('iris').mean()
# Out:
#                  sepallength  sepalwidth  petallength  petalwidth
# iris
# Iris-setosa            5.006     3.41800     1.464000       0.244
# Iris-versicolor        5.936     2.77000     4.260000       1.326
# Iris-virginica         6.588     2.97551     5.567347       2.026

# %% [markdown]
# Prikaži usporedbu medijan vrijednosti za sve nezavisne varijable.

# %%
df.select_dtypes(include=['number']).median().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Min max transformacija
# Napravi normalizaciju nezavisnih varijabli.

# %%
df['sepw_min_max'] = (df['sepalwidth']-df.sepalwidth.min())/(df.sepalwidth.max()-df.sepalwidth.min())
df['sepl_min_max'] = (df['sepallength']-df.sepallength.min())/(df.sepallength.max()-df.sepallength.min())
df['petw_min_max'] = (df['petalwidth']-df.petalwidth.min())/(df.petalwidth.max()-df.petalwidth.min())
df['petl_min_max'] = (df['petallength']-df.petallength.min())/(df.petallength.max()-df.petallength.min())


df.groupby('iris').head(3)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth             iris  \
# 0            5.1         3.5          1.4         0.2      Iris-setosa
# 1            4.9         3.0          1.4         0.2      Iris-setosa
# 2            4.7         3.2          1.3         0.2      Iris-setosa
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 51           6.4         3.2          4.5         1.5  Iris-versicolor
# 52           6.9         3.1          4.9         1.5  Iris-versicolor
# 100          6.3         3.3          6.0         2.5   Iris-virginica
# 101          5.8         2.7          5.1         1.9   Iris-virginica
# 102          7.1         3.0          5.9         2.1   Iris-virginica
#
#      sepw_min_max  sepl_min_max  petw_min_max  petl_min_max
# 0        0.625000      0.222222      0.041667      0.067797
# 1        0.416667      0.166667      0.041667      0.067797
# 2        0.500000      0.111111      0.041667      0.050847
# 50       0.500000      0.750000      0.541667      0.627119
# 51       0.500000      0.583333      0.583333      0.593220
# 52       0.458333      0.722222      0.583333      0.661017
# 100      0.541667      0.555556      1.000000      0.847458
# 101      0.291667      0.416667      0.750000      0.694915
# 102      0.416667      0.777778      0.833333      0.830508

# %% [markdown]
# ### Z transformacija
# Napravi Z transformaciju nezavisnih varijabli.

# %%
df['sepw_z'] = (df['sepalwidth']-df.sepalwidth.mean())/(df.sepalwidth.std())
df['sepl_z'] = (df['sepallength']-df.sepallength.mean())/(df.sepallength.std())
df['petw_z'] = (df['petalwidth']-df.petalwidth.mean())/(df.petalwidth.std())
df['petl_z'] = (df['petallength']-df.petallength.mean())/(df.petallength.std())

df.groupby('iris').head(3)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth             iris  \
# 0            5.1         3.5          1.4         0.2      Iris-setosa
# 1            4.9         3.0          1.4         0.2      Iris-setosa
# 2            4.7         3.2          1.3         0.2      Iris-setosa
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 51           6.4         3.2          4.5         1.5  Iris-versicolor
# 52           6.9         3.1          4.9         1.5  Iris-versicolor
# 100          6.3         3.3          6.0         2.5   Iris-virginica
# 101          5.8         2.7          5.1         1.9   Iris-virginica
# 102          7.1         3.0          5.9         2.1   Iris-virginica
#
#      sepw_min_max  sepl_min_max  petw_min_max  petl_min_max    sepw_z  \
# 0        0.625000      0.222222      0.041667      0.067797  1.023214
# 1        0.416667      0.166667      0.041667      0.067797 -0.126551
# 2        0.500000      0.111111      0.041667      0.050847  0.333355
# 50       0.500000      0.750000      0.541667      0.627119  0.333355
# 51       0.500000      0.583333      0.583333      0.593220  0.333355
# 52       0.458333      0.722222      0.583333      0.661017  0.103402
# 100      0.541667      0.555556      1.000000      0.847458  0.563308
# 101      0.291667      0.416667      0.750000      0.694915 -0.816411
# 102      0.416667      0.777778      0.833333      0.830508 -0.126551
#
#        sepl_z    petw_z    petl_z
# 0   -0.897674 -1.308593 -1.329919
# 1   -1.139200 -1.308593 -1.329919
# 2   -1.380727 -1.308593 -1.386471
# 50   1.396829  0.263815  0.536294
# 51   0.672249  0.394849  0.423190
# 52   1.276066  0.394849  0.649398
# 100  0.551486  1.705189  1.271469
# 101 -0.052331  0.918985  0.762502
# 102  1.517592  1.181053  1.214917

# %% [markdown]
# ### N najvećih i najmanjih vrijednosti
# Prikaži 5 najvećih i pet najmanjih vrijednosti po Z-skaliranim vrijednostima

# %%
#demo
print(df.nlargest(5, 'sepalwidth'))
print(df.nsmallest(5, 'sepalwidth'))
# Out:
#     sepallength  sepalwidth  petallength  petalwidth         iris  \
# 15          5.7         4.4          1.5         0.4  Iris-setosa
# 33          5.5         4.2          1.4         0.2  Iris-setosa
# 32          5.2         4.1          1.5         0.1  Iris-setosa
# 14          5.8         4.0          1.2         0.2  Iris-setosa
# 5           5.4         3.9          1.7         0.4  Iris-setosa
#
#     sepw_min_max  sepl_min_max  petw_min_max  petl_min_max    sepw_z  \
# 15      1.000000      0.388889      0.125000      0.084746  3.092792
# 33      0.916667      0.333333      0.041667      0.067797  2.632886
# 32      0.875000      0.250000      0.000000      0.084746  2.402933
# 14      0.833333      0.416667      0.041667      0.033898  2.172980
# 5       0.791667      0.305556      0.125000      0.118644  1.943027
#
#       sepl_z    petw_z    petl_z
# 15 -0.173094 -1.046525 -1.273367
# 33 -0.414621 -1.308593 -1.329919
# 32 -0.776911 -1.439627 -1.273367
# 14 -0.052331 -1.308593 -1.443023
# 5  -0.535384 -1.046525 -1.160263
#      sepallength  sepalwidth  petallength  petalwidth             iris  \
# 60           5.0         2.0          3.5         1.0  Iris-versicolor
# 62           6.0         2.2          4.0         1.0  Iris-versicolor
# 68           6.2         2.2          4.5         1.5  Iris-versicolor
# 119          6.0         2.2          5.0         1.5   Iris-virginica
# 41           4.5         2.3          1.3         0.3      Iris-setosa
#
#      sepw_min_max  sepl_min_max  petw_min_max  petl_min_max    sepw_z  \
# 60       0.000000      0.194444      0.375000      0.423729 -2.426083
# 62       0.083333      0.472222      0.375000      0.508475 -1.966176
# 68       0.083333      0.527778      0.583333      0.593220 -1.966176
# 119      0.083333      0.472222      0.583333      0.677966 -1.966176
# 41       0.125000      0.055556      0.083333      0.050847 -1.736223
#
#        sepl_z    petw_z    petl_z
# 60  -1.018437 -0.260321 -0.142329
# 62   0.189196 -0.260321  0.140431
# 68   0.430722  0.394849  0.423190
# 119  0.189196  0.394849  0.705950
# 41  -1.622254 -1.177559 -1.386471

# %% [markdown]
# ### Provjera missing vrijednosti
# Prikažimo redke s nedostajućim vrijednostima.

# %%
df[df.isna().any(axis=1)]
# Out:
#      sepallength  sepalwidth  petallength  petalwidth            iris  \
# 103          6.3         NaN          5.6         1.8  Iris-virginica
# 126          6.2         2.8          NaN         1.8  Iris-virginica
#
#      sepw_min_max  sepl_min_max  petw_min_max  petl_min_max    sepw_z  \
# 103           NaN      0.555556      0.708333      0.779661       NaN
# 126      0.333333      0.527778      0.708333           NaN -0.586458
#
#        sepl_z    petw_z    petl_z
# 103  0.551486  0.787951  1.045261
# 126  0.430722  0.787951       NaN

# %% [markdown]
# Izbacimo redke s nedostajućim vrijednostima.

# %%
df=df.dropna()
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [sepallength, sepalwidth, petallength, petalwidth, iris, sepw_min_max, sepl_min_max, petw_min_max, petl_min_max, sepw_z, sepl_z, petw_z, petl_z]
# Index: []

# %% [markdown]
# ### Kreiranje razreda temeljem min max transformacije
# Trenutno su nam vrijednosti kontinuirane. Napravimo razrede

# %%
min_max_bin = pd.qcut(df.sepw_min_max,5)
df = df.assign(Razredi_sepw=min_max_bin)






df.groupby('iris').head(3)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth             iris  \
# 0            5.1         3.5          1.4         0.2      Iris-setosa
# 1            4.9         3.0          1.4         0.2      Iris-setosa
# 2            4.7         3.2          1.3         0.2      Iris-setosa
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 51           6.4         3.2          4.5         1.5  Iris-versicolor
# 52           6.9         3.1          4.9         1.5  Iris-versicolor
# 100          6.3         3.3          6.0         2.5   Iris-virginica
# 101          5.8         2.7          5.1         1.9   Iris-virginica
# 102          7.1         3.0          5.9         2.1   Iris-virginica
#
#      sepw_min_max  sepl_min_max  petw_min_max  petl_min_max    sepw_z  \
# 0        0.625000      0.222222      0.041667      0.067797  1.023214
# 1        0.416667      0.166667      0.041667      0.067797 -0.126551
# 2        0.500000      0.111111      0.041667      0.050847  0.333355
# 50       0.500000      0.750000      0.541667      0.627119  0.333355
# 51       0.500000      0.583333      0.583333      0.593220  0.333355
# 52       0.458333      0.722222      0.583333      0.661017  0.103402
# 100      0.541667      0.555556      1.000000      0.847458  0.563308
# 101      0.291667      0.416667      0.750000      0.694915 -0.816411
# 102      0.416667      0.777778      0.833333      0.830508 -0.126551
#
#        sepl_z    petw_z    petl_z     Razredi_sepw
# 0   -0.897674 -1.308593 -1.329919     (0.583, 1.0]
# 1   -1.139200 -1.308593 -1.329919   (0.292, 0.417]
# 2   -1.380727 -1.308593 -1.386471   (0.458, 0.583]
# 50   1.396829  0.263815  0.536294   (0.458, 0.583]
# 51   0.672249  0.394849  0.423190   (0.458, 0.583]
# 52   1.276066  0.394849  0.649398   (0.417, 0.458]
# 100  0.551486  1.705189  1.271469   (0.458, 0.583]
# 101 -0.052331  0.918985  0.762502  (-0.001, 0.292]
# 102  1.517592  1.181053  1.214917   (0.292, 0.417]

# %% [markdown]
# Prikaži sve vrijednosti razreda za sve četiri nezavisne varijable.

# %% [markdown]
# ###  Promjena vrijednosti prema višestruktim kriterijem unutar frame-a
# Napravi nove "Dummy" varijable koje će prikazati da li je vrijednost varijable iznad prosjeka i manja od trećeg kvartila.

# %%
df['Dummy_sepw'] = 0

df.loc[(df['sepalwidth'] > df['sepalwidth'].mean()) & (df['sepalwidth'] < df['sepalwidth'].quantile(q=0.75)) ,'Dummy_sepw'] = 1
df.groupby('iris').head(3)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth             iris  \
# 0            5.1         3.5          1.4         0.2      Iris-setosa
# 1            4.9         3.0          1.4         0.2      Iris-setosa
# 2            4.7         3.2          1.3         0.2      Iris-setosa
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 51           6.4         3.2          4.5         1.5  Iris-versicolor
# 52           6.9         3.1          4.9         1.5  Iris-versicolor
# 100          6.3         3.3          6.0         2.5   Iris-virginica
# 101          5.8         2.7          5.1         1.9   Iris-virginica
# 102          7.1         3.0          5.9         2.1   Iris-virginica
#
#      sepw_min_max  sepl_min_max  petw_min_max  petl_min_max    sepw_z  \
# 0        0.625000      0.222222      0.041667      0.067797  1.023214
# 1        0.416667      0.166667      0.041667      0.067797 -0.126551
# 2        0.500000      0.111111      0.041667      0.050847  0.333355
# 50       0.500000      0.750000      0.541667      0.627119  0.333355
# 51       0.500000      0.583333      0.583333      0.593220  0.333355
# 52       0.458333      0.722222      0.583333      0.661017  0.103402
# 100      0.541667      0.555556      1.000000      0.847458  0.563308
# 101      0.291667      0.416667      0.750000      0.694915 -0.816411
# 102      0.416667      0.777778      0.833333      0.830508 -0.126551
#
#        sepl_z    petw_z    petl_z     Razredi_sepw  Dummy_sepw
# 0   -0.897674 -1.308593 -1.329919     (0.583, 1.0]           0
# 1   -1.139200 -1.308593 -1.329919   (0.292, 0.417]           0
# 2   -1.380727 -1.308593 -1.386471   (0.458, 0.583]           1
# 50   1.396829  0.263815  0.536294   (0.458, 0.583]           1
# 51   0.672249  0.394849  0.423190   (0.458, 0.583]           1
# 52   1.276066  0.394849  0.649398   (0.417, 0.458]           1
# 100  0.551486  1.705189  1.271469   (0.458, 0.583]           0
# 101 -0.052331  0.918985  0.762502  (-0.001, 0.292]           0
# 102  1.517592  1.181053  1.214917   (0.292, 0.417]           0

# %% [markdown]
# ### Selekcija  sa upisom rezultata u novi frame
# Napravimo novi dataframe s podacima nastalim uporabom kriterija na posojećem dataframeu. Napravi selekciju za podatke između prvog i trećeg kvartila. Ispiši broj redaka u svakom od novih dataframeova (metoda shape).

# %%
demo = df[(df.sepalwidth > 3) &  (df.sepalwidth< 4)]

newdf_sepw = df[(df.sepalwidth > df.sepalwidth.quantile(q=0.25)) &  (df.sepalwidth< df.sepalwidth.quantile(q=0.75))]
newdf_sepw.shape
# Out:
# (60, 15)

# %%
df.sepalwidth.quantile(q=0.25)
# Out:
# np.float64(2.8)

# %% [markdown]
# ### Brisanje retka unutar data frame-a
# Sada iz novih dataframeove obriši retke u kojima je vrijednost jednaka drugom kvartilu.  Ispiši broj redaka u svakom od novih dataframeova (metoda shape) i pogledaj da li je broj manji nego prije

# %%
demo = demo.drop(demo[demo.sepalwidth == 3.5].index)
print("demo.shape nakon brisanja:", demo.shape)

newdf_sepw = newdf_sepw.drop(newdf_sepw[newdf_sepw.sepalwidth == df.sepalwidth.quantile(q=0.5)].index)
print("newdf_sepw.shape nakon brisanja:", newdf_sepw.shape)
# Out:
# demo.shape nakon brisanja: (57, 15)
# newdf_sepw.shape nakon brisanja: (34, 15)

# %% [markdown]
# ### Prebacivanje kolone iz frame-a u listu
# Napravimo četiri nove liste s vrijednostima iz prethodna četiri dataframea.

# %%
demo['sepalwidth']
# Out:
# 2      3.2
# 3      3.1
# 4      3.6
# 5      3.9
# 6      3.4
# 7      3.4
# 9      3.1
# 10     3.7
# 11     3.4
# 16     3.9
# 18     3.8
# 19     3.8
# 20     3.4
# 21     3.7
# 22     3.6
# 23     3.3
# 24     3.4
# 26     3.4
# 28     3.4
# 29     3.2
# 30     3.1
# 31     3.4
# 34     3.1
# 35     3.2
# 37     3.1
# 39     3.4
# 42     3.2
# 44     3.8
# 46     3.8
# 47     3.2
# 48     3.7
# 49     3.3
# 50     3.2
# 51     3.2
# 52     3.1
# 56     3.3
# 65     3.1
# 70     3.2
# 85     3.4
# 86     3.1
# 100    3.3
# 109    3.6
# 110    3.2
# 115    3.2
# 117    3.8
# 120    3.2
# 124    3.3
# 125    3.2
# 131    3.8
# 136    3.4
# 137    3.1
# 139    3.1
# 140    3.1
# 141    3.1
# 143    3.2
# 144    3.3
# 148    3.4
# Name: sepalwidth, dtype: float64

# %%
Lista_demo=list()
Lista_demo = demo['sepalwidth']

# %% [markdown]
# ### Zadaća

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as p
df.plot.hist(title='Histogram')
# Out:
# <Axes: title={'center': 'Histogram'}, ylabel='Frequency'>

# %% [markdown]
# Napravi prikaz u kojem se prikazuje usporedba srednjih vrijednosti po tipovima irisa.

# %%
df.groupby('iris')[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='iris'>

# %% [markdown]
# Napravi prikaz u kojem se prikazuje distribucija vrijednosti "sepallength" po tipovima irisa.

# %%
df.boxplot(column='sepallength', by='iris')
# Out:
# <Axes: title={'center': 'sepallength'}, xlabel='iris'>
