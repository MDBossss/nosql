# %% [markdown]
# <img src="vua.png">

# %% [markdown]
# Koristeći Pandas analizirat će mo podatke o vido igrama skinute s IGN-a (jedan od stranica sa recenzijama). Analiziranjem recenzija naučit će mo osnove Pandas biblioteke.

# %% [markdown]
# Probat će mo pronaći odgovore tipa:
# Da li igre tipa Witcher 3 dobijaju bolje recenzije na PS4 od onih na Xbox One?

# %% [markdown]
# # Učitavanje podataka u Pandas

# %% [markdown]
# Prvi korak je učitavanje podataka. Podaci su spremljeni u csv formatu (comma-separated values), gdje je svaki redak odvojen karakterom za novu liniju a stupci s zarezom (,). Dokument se nalazi u mapi Lab02 podimenom ign.csv.
# Kako radimo na linux poslužitelju prvo pogledamo imamo li dokument i njegov izgled dokumenta.

# %% [markdown]
# Uz pomoć uskličnika (!) na početku retka možemo izvršavati *shell* naredbe. Pa probajmo izvršiti naredbu *ls*

# %%
! ls
# Out:
# DecimalnoSkaliranje.png  Min-Max.png  Pandas.ipynb	cars.csv
# Euklidska_distanca.png	 Pandas.html  Z-skaliranje.png	ign.csv

# %% [markdown]
# Dobili smo popis svih datoteka u radnoj mapi. sad pogledajmo kako izgleda datoteka ign.csv. To možemo postići naredbm *cat* za ispis cjele datoteke ili *head* za prikaz prvih 10 redaka.

# %%
! head ign.csv
# Out:
# ,score_phrase,title,url,platform,score,genre,editors_choice,release_year,release_month,release_day
# 0,Amazing,LittleBigPlanet PS Vita,/games/littlebigplanet-vita/vita-98907,PlayStation Vita,9.0,Platformer,Y,2012,9,12
# 1,Amazing,LittleBigPlanet PS Vita -- Marvel Super Hero Edition,/games/littlebigplanet-ps-vita-marvel-super-hero-edition/vita-20027059,PlayStation Vita,9.0,Platformer,Y,2012,9,12
# 2,Great,Splice: Tree of Life,/games/splice/ipad-141070,iPad,8.5,Puzzle,N,2012,9,12
# 3,Great,NHL 13,/games/nhl-13/xbox-360-128182,Xbox 360,8.5,Sports,N,2012,9,11
# 4,Great,NHL 13,/games/nhl-13/ps3-128181,PlayStation 3,8.5,Sports,N,2012,9,11
# 5,Good,Total War Battles: Shogun,/games/total-war-battles-shogun/mac-142565,Macintosh,7.0,Strategy,N,2012,9,11
# 6,Awful,Double Dragon: Neon,/games/double-dragon-neon/xbox-360-131320,Xbox 360,3.0,Fighting,N,2012,9,11
# 7,Amazing,Guild Wars 2,/games/guild-wars-2/pc-896298,PC,9.0,RPG,Y,2012,9,11
# 8,Awful,Double Dragon: Neon,/games/double-dragon-neon/ps3-131321,PlayStation 3,3.0,Fighting,N,2012,9,11

# %% [markdown]
# Kako vidite svaki redak sadrži podatke jedne recenzije, a stupci informacije o igri:
#  * `score_phrase` – IGN opis igre. povezano s ocjenom
#  * `title` – naziv igre
#  * `url` – URL pune recenzije
#  * `platform` – platforma na kojoj je napravljena recenzija (PC, PS4, ...)
#  * `score` – ocjena (1.0 to 10.0)
#  * `genre` – žanr igre
#  * `editors_choice` – Preporuka uredništva (N - ne, Y - da)
#  * `release_year` – godina izdavanja
#  * `release_month` – mjesec izdavanja
#  * `release_day` – dan izdavanja
# Tu je još i prvi stupac s indeksom retka.
#
# ### Za obradu podataka potrebno ih je učitati iz csv dokumenta

# %% [markdown]
# Prvo moramo učitati *Pandas* biblioteku s naredbom *import*. Nakon naziva biblioteke možemo dodati i parametar *as* pa napisati skračeni naziv koji kasnije možemo koristiti za pristup funkcijama biblioteke.

# %%
import pandas as pd

# %% [markdown]
# Pandas funkcijom *read_csv* možemo učitati ing.csv datoteku u varijablu *recenzije*.

# %%
recenzije = pd.read_csv("ign.csv")

# %% [markdown]
# Nakon učitavanja u *DataFrame*, *Pandas* nam omogućuje da pogledamo cjeli skup podataka ili samo prvih ili zadnjih *N* redaka. To su funkcije:
#  * DataFrame.head() – ispis prvih *N* redaka. Ako ne definiramo N bit će 5.
#  * DataFrame.tail() – ispis zadnjih *N* redaka. Ako ne definiramo N bit će 5.
# Korištenjem metode *head* pogledajmo prvih 5 redaka

# %%
recenzije.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %% [markdown]
# Korištenjem svojstva *shape* možemo vidjeti koliko redaka i stupaca ima naš DataFrame:

# %%
recenzije.shape
# Out:
# (18625, 11)

# %% [markdown]
# Ako je učitavanje proteklo bez problema trebali bi imati 18625 redaka i 11 stupaca (18625, 11)

# %% [markdown]
# Kao što možete uočiti *Pandas* nam omogućuje da imamo različite tipove podataka u različitim stupcima.

# %% [markdown]
# Prethodno smo koristili metodu *head* da bi prikazali retke na početku DataFramea. Isto smo mogli postići i sa metodom *iloc*.
# Sljedeća naredba vratit će isti rezultat kao i prethodno pokrenuta s metodom hjead.

# %%
recenzije.iloc[:5,:]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %% [markdown]
# U metodi *iloc* definirali smo da želimo retke 0:5.
#  * 0:5 - uzima retke s od onog s indeksom 0 do onog s indeksom 5 ali zadnjeg ne uključuje u rezultat.
#
# Dobili smo retke s indeksom 0,1,2,3 i 4.
# Jednako tako isti rezltat smo mogli postići da smo napisali :5, jer ako ne stavimo prvi broj *Pandas* predpostavlja da želimo odgovor od početka DataFramea, odnosno ako izostavimo drug da želimo do kraja.
#
# Kako smo željei sve stupce jednostavno smo izostavili oba broja.
#
# Neki primjeri indeksiranja s opisom:
#  * recenzije.iloc[0:5,:] - prvih 5 redaka i svi stupci
#  * recenzije.iloc[:,:] – cjeli DataFrame
#  * recenzije.iloc[5:,5:] – redci od 5. do kraja i stupci od 5. do kraja
#  * recenzije.iloc[:,0] – prvi stupac sa svim redcima
#  * recenzije.iloc[9,:] – 10. redak sa svim stupcima
#
# Indeksiranje je jako slično onome u biblioteci *NumPy*. Ako želite naučiti više o tome upute možete pogledati na linku [NumPy](http://www.dataquest.io/blog/numpy-tutorial-python/).

# %% [markdown]
# Sada kada znamo označavati po pozicijama maknimo prvi stupac jer nema korisnih informacija.
#
# Našoj Varijabli *recenzije* dodjeljujemo rezlltatz metode *iloc*.

# %%
recenzije = recenzije.iloc[:,1:]

# %%
recenzije.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %% [markdown]
# Ono što na *Pandas* još omogućuje da indeksiramo po nazivima redaka i stupaca. Kada želimo raditi s nazivima umjesto metode *iloc* koristimo metodu *loc*.
#
# Kada pokrenemo sljedeću naredbu dobit će morezultaa kao da smo koristili prethodnu metodu *iloc*.

# %%
recenzije.loc[0:5,:]
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
# 5         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
# 5         /games/total-war-battles-shogun/mac-142565         Macintosh    7.0
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11
# 5    Strategy              N          2012              9           11

# %% [markdown]
# To je tako zato što su nam redci indeksirani brojevima.
#
# Provjerimo s propertijem *index*.

# %%
recenzije.index
# Out:
# RangeIndex(start=0, stop=18625, step=1)

# %% [markdown]
# Indeksi nisu uvjek jednaki s pozicijom retka, ako primjerice u neku drugu varijablu *neki_redci* pospremino retke od 10 do 20 iz *recenzije* i prikažemo novi DataFrame vidimo da to su indeksi ostali.

# %%
neki_redci = recenzije.iloc[10:20,]
neki_redci
# Out:
#    score_phrase                            title  \
# 10         Good          Tekken Tag Tournament 2
# 11         Good          Tekken Tag Tournament 2
# 12         Good                       Wild Blood
# 13      Amazing                Mark of the Ninja
# 14      Amazing                Mark of the Ninja
# 15         Okay  Home: A Unique Horror Adventure
# 16         Okay  Home: A Unique Horror Adventure
# 17        Great              Avengers Initiative
# 18     Mediocre             Way of the Samurai 4
# 19         Good      JoJo's Bizarre Adventure HD
#
#                                                   url       platform  score  \
# 10          /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11     /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                    /games/wild-blood/iphone-139363         iPhone    7.0
# 13    /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 14          /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
# 15  /games/home-a-unique-horror-adventure/mac-2001...      Macintosh    6.5
# 16    /games/home-a-unique-horror-adventure/pc-137135             PC    6.5
# 17           /games/avengers-initiative/iphone-141579         iPhone    8.0
# 18              /games/way-of-the-samurai-4/ps3-23516  PlayStation 3    5.5
# 19     /games/jojos-bizarre-adventure/xbox-360-137717       Xbox 360    7.0
#
#                 genre editors_choice  release_year  release_month  release_day
# 10           Fighting              N          2012              9           11
# 11           Fighting              N          2012              9           11
# 12                NaN              N          2012              9           10
# 13  Action, Adventure              Y          2012              9            7
# 14  Action, Adventure              Y          2012              9            7
# 15          Adventure              N          2012              9            6
# 16          Adventure              N          2012              9            6
# 17             Action              N          2012              9            5
# 18  Action, Adventure              N          2012              9            3
# 19           Fighting              N          2012              9            3

# %% [markdown]
# Ako probamo sad pristupiti nekom retku koji nije u DataFrameu rezultat neće odgovarati onome što smo željeli.

# %%
neki_redci.loc[5:9,:]
# Out:
# Empty DataFrame
# Columns: [score_phrase, title, url, platform, score, genre, editors_choice, release_year, release_month, release_day]
# Index: []

# %% [markdown]
# A ako to napravimo s metodom *iloc* dobit će mo željene retke.

# %%
neki_redci.iloc[5:9,:]
# Out:
#    score_phrase                            title  \
# 15         Okay  Home: A Unique Horror Adventure
# 16         Okay  Home: A Unique Horror Adventure
# 17        Great              Avengers Initiative
# 18     Mediocre             Way of the Samurai 4
#
#                                                   url       platform  score  \
# 15  /games/home-a-unique-horror-adventure/mac-2001...      Macintosh    6.5
# 16    /games/home-a-unique-horror-adventure/pc-137135             PC    6.5
# 17           /games/avengers-initiative/iphone-141579         iPhone    8.0
# 18              /games/way-of-the-samurai-4/ps3-23516  PlayStation 3    5.5
#
#                 genre editors_choice  release_year  release_month  release_day
# 15          Adventure              N          2012              9            6
# 16          Adventure              N          2012              9            6
# 17             Action              N          2012              9            5
# 18  Action, Adventure              N          2012              9            3

# %% [markdown]
# Kako smo prethodno spomenuli metodom *loc* možemo nazivima pristupati i stupcima. Umjesto da pamtimo pozicije stupaca možemo pristupati s nazivima.

# %%
recenzije.loc[:5,"score"]
# Out:
# 0    9.0
# 1    9.0
# 2    8.5
# 3    8.5
# 4    8.5
# 5    7.0
# Name: score, dtype: float64

# %% [markdown]
# Jadnako tako možemo prosljeriti i listu stupaca.

# %%
recenzije.loc[:5,["score", "release_year"]]
# Out:
#    score  release_year
# 0    9.0          2012
# 1    9.0          2012
# 2    8.5          2012
# 3    8.5          2012
# 4    8.5          2012
# 5    7.0          2012

# %% [markdown]
# Dosad smo vidjeli da pojedinom stupcu možemo pristupiti kroz metode *iloc* i *loc* , pa primjerice naredbe:
#  * recenzije.iloc[:,1]
#  * recenzije.loc[:,"score_phrase"]
#
# vračaju drugi stupac.
#
# Postoji i treći (najlakši) način za pristupiti stupcu, gdje nakon naziva DataFramea jednostavno u uglatim zagradama pošaljemo naziv stupaca ili listu naziva stupaca.

# %%
recenzije["score"]
# Out:
# 0         9.0
# 1         9.0
# 2         8.5
# 3         8.5
# 4         8.5
# 5         7.0
# 6         3.0
# 7         9.0
# 8         3.0
# 9         7.0
# 10        7.5
# 11        7.5
# 12        7.0
# 13        9.0
# 14        9.0
# 15        6.5
# 16        6.5
# 17        8.0
# 18        5.5
# 19        7.0
# 20        7.0
# 21        7.5
# 22        7.5
# 23        7.5
# 24        9.0
# 25        7.0
# 26        9.0
# 27        7.5
# 28        8.0
# 29        6.5
#          ...
# 18595     4.4
# 18596     6.5
# 18597     4.9
# 18598     6.8
# 18599     7.0
# 18600     7.4
# 18601     7.4
# 18602     7.4
# 18603     7.8
# 18604     8.6
# 18605     6.0
# 18606     6.4
# 18607     7.0
# 18608     5.4
# 18609     8.0
# 18610     6.0
# 18611     5.8
# 18612     7.8
# 18613     8.0
# 18614     9.2
# 18615     9.2
# 18616     7.5
# 18617     8.4
# 18618     9.1
# 18619     7.9
# 18620     7.6
# 18621     9.0
# 18622     5.8
# 18623    10.0
# 18624    10.0
# Name: score, Length: 18625, dtype: float64

# %%
recenzije[["score", "release_year"]]

# %% [markdown]
# Kada pristupama samo jednom stupcu rezultat postaje Pandas serija, dok više stupaca je uvjek Pandas DataFrame.

# %%
type(recenzije)
# Out:
# pandas.core.frame.DataFrame

# %%
type(recenzije["score"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Da bi bolje shvatili kako rade možemo i ručno napraviti Seriju

# %%
s1 = pd.Series([1,2])

# %%
s1

# %% [markdown]
# Serije mogu imati bilo koji tip podataka. Idemo napraviti novu s stringovima.

# %%
s2 = pd.Series(["Boris Yeltsin", "Mikhail Gorbachev"])

# %%
s2

# %% [markdown]
# Sad kad imamo dvije serije od njih možemo napraviti DataFrame

# %%
pd.DataFrame([s1,s2])

# %% [markdown]
# Isti rezultat smo mogli napraviti i slanjem liste listi.

# %%
pd.DataFrame(
    [
        [1,2],
        ["Boris Yeltsin", "Mikhail Gorbachev"]
    ]
)

# %% [markdown]
# Jednako tako možemo i specificirati nazive stupaca i nazive redaka kod definiranja DataFramea.

# %%
frame = pd.DataFrame(
    [
        [1,2],
        ["Boris Yeltsin", "Mikhail Gorbachev"]
    ],
    index=["row1", "row2"],
    columns=["column1", "column2"]
)
frame

# %% [markdown]
# Postoji i drugi način u kojem možemo poslati rječnik (dictionary) u DataFrame

# %%
frame = pd.DataFrame(
    {
        "column1": [1, "Boris Yeltsin"],
        "column2": [2, "Mikhail Gorbachev"]
    }
)
frame

# %% [markdown]
# ## Metode na Serijama i DataFramovima

# %% [markdown]
# Skoro sve metoda koje koristimo na DataFrameu možemo koristiti i na Serijama. Primjerice metoda *head* vrača prvih N zapisa u stupcu.

# %%
recenzije["title"].head()
# Out:
# 0                              LittleBigPlanet PS Vita
# 1    LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                 Splice: Tree of Life
# 3                                               NHL 13
# 4                                               NHL 13
# Name: title, dtype: object

# %% [markdown]
# Možemo koristiti i metodu *mean* za srednju vrijednost.

# %%
recenzije["score"].mean()
# Out:
# 6.950459060402666

# %%
recenzije.mean()
# Out:
# score               6.950459
# release_year     2006.515329
# release_month       7.138470
# release_day        15.603866
# dtype: float64

# %% [markdown]
# Kao što vidite kad se pokrene *mean* na DataFrameu rezultat je samo od stupaca koji su numerički.
#
# Ako nam je potrebno možemo promjeniti i os (axis) računanja. Predefinirano je axis=0 pa rezultati su vezani za stupce, ako pak stavimo axis=1 onda će se rezultat odnositi na retke.

# %%
recenzije.mean(axis=1)
# Out:
# 0        510.500
# 1        510.500
# 2        510.375
# 3        510.125
# 4        510.125
# 5        509.750
# 6        508.750
# 7        510.250
# 8        508.750
# 9        509.750
# 10       509.875
# 11       509.875
# 12       509.500
# 13       509.250
# 14       509.250
# 15       508.375
# 16       508.375
# 17       508.500
# 18       507.375
# 19       507.750
# 20       507.750
# 21       514.625
# 22       514.625
# 23       514.625
# 24       515.000
# 25       514.250
# 26       514.750
# 27       514.125
# 28       514.250
# 29       513.625
#           ...
# 18595    510.850
# 18596    510.875
# 18597    510.225
# 18598    510.700
# 18599    510.750
# 18600    512.600
# 18601    512.600
# 18602    512.600
# 18603    512.450
# 18604    512.400
# 18605    511.500
# 18606    508.600
# 18607    510.750
# 18608    510.350
# 18609    510.750
# 18610    510.250
# 18611    508.700
# 18612    509.200
# 18613    508.000
# 18614    515.050
# 18615    515.050
# 18616    508.375
# 18617    508.600
# 18618    515.025
# 18619    514.725
# 18620    514.650
# 18621    515.000
# 18622    513.950
# 18623    515.000
# 18624    515.000
# Length: 18625, dtype: float64

# %% [markdown]
# Naravno imamo i drugih metoda:
#  * DataFrame.corr – ispisuje koeficjent korelacije stupaca u DataFrameu
#  * DataFrame.count – ispisuje broj non-null vrjednosti u stupcima
#  * DataFrame.max – ispisuje največi broj u stupcima
#  * DataFrame.min – ispisuje najmanji broj u stupcima
#  * DataFrame.median – ispisuje median u stupcima
#  * DataFrame.std – ispisuje standardnu devijaciju u stupcima

# %% [markdown]
# Pogledamo korelaciju na našem DataFrameu

# %%
recenzije.corr()
# Out:
#                   score  release_year  release_month  release_day
# score          1.000000      0.062716       0.007632     0.020079
# release_year   0.062716      1.000000      -0.115515     0.016867
# release_month  0.007632     -0.115515       1.000000    -0.067964
# release_day    0.020079      0.016867      -0.067964     1.000000

# %% [markdown]
# Kada pogledamo tablicu korelacije vidimo da niti jedna od naših numeričkih varijabli nije korelirana s rezultatom (score)

# %% [markdown]
# ### Matematičke operacije s Pandasom

# %% [markdown]
# Na serijama možemo jednostavno izvršavati matematičke operacije.
#
# Možemo koristiti sve matematičke operatore iz Pythona (+, -, \*, /, ^) i primjenit će se na svakom elementu DataFramea ili Serije.

# %%
recenzije["score"] / 2
# Out:
# 0        4.50
# 1        4.50
# 2        4.25
# 3        4.25
# 4        4.25
# 5        3.50
# 6        1.50
# 7        4.50
# 8        1.50
# 9        3.50
# 10       3.75
# 11       3.75
# 12       3.50
# 13       4.50
# 14       4.50
# 15       3.25
# 16       3.25
# 17       4.00
# 18       2.75
# 19       3.50
# 20       3.50
# 21       3.75
# 22       3.75
# 23       3.75
# 24       4.50
# 25       3.50
# 26       4.50
# 27       3.75
# 28       4.00
# 29       3.25
#          ...
# 18595    2.20
# 18596    3.25
# 18597    2.45
# 18598    3.40
# 18599    3.50
# 18600    3.70
# 18601    3.70
# 18602    3.70
# 18603    3.90
# 18604    4.30
# 18605    3.00
# 18606    3.20
# 18607    3.50
# 18608    2.70
# 18609    4.00
# 18610    3.00
# 18611    2.90
# 18612    3.90
# 18613    4.00
# 18614    4.60
# 18615    4.60
# 18616    3.75
# 18617    4.20
# 18618    4.55
# 18619    3.95
# 18620    3.80
# 18621    4.50
# 18622    2.90
# 18623    5.00
# 18624    5.00
# Name: score, Length: 18625, dtype: float64

# %% [markdown]
# I jednoako tako rezultat tih operacija možemo pospremiti u novi stupac.

# %%
recenzije["novi"] = recenzije["score"] / recenzije["release_day"]

# %%
recenzije
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2            Great                               Splice: Tree of Life
# 3            Great                                             NHL 13
# 4            Great                                             NHL 13
# 5             Good                          Total War Battles: Shogun
# 6            Awful                                Double Dragon: Neon
# 7          Amazing                                       Guild Wars 2
# 8            Awful                                Double Dragon: Neon
# 9             Good                          Total War Battles: Shogun
# 10            Good                            Tekken Tag Tournament 2
# 11            Good                            Tekken Tag Tournament 2
# 12            Good                                         Wild Blood
# 13         Amazing                                  Mark of the Ninja
# 14         Amazing                                  Mark of the Ninja
# 15            Okay                    Home: A Unique Horror Adventure
# 16            Okay                    Home: A Unique Horror Adventure
# 17           Great                                Avengers Initiative
# 18        Mediocre                               Way of the Samurai 4
# 19            Good                        JoJo's Bizarre Adventure HD
# 20            Good                        JoJo's Bizarre Adventure HD
# 21            Good                           Mass Effect 3: Leviathan
# 22            Good                           Mass Effect 3: Leviathan
# 23            Good                           Mass Effect 3: Leviathan
# 24         Amazing                Dark Souls (Prepare to Die Edition)
# 25            Good                                           Symphony
# 26         Amazing                                            Bastion
# 27            Good                  Tom Clancy's Ghost Recon Phantoms
# 28           Great                           Thirty Flights of Loving
# 29            Okay                                          Legasista
# ...            ...                                                ...
# 18595          Bad                                       Ghostbusters
# 18596         Okay                                         Necropolis
# 18597          Bad                                      7 Days to Die
# 18598         Okay                                               Furi
# 18599         Good                                         Pokemon Go
# 18600         Good                                  Hitman: Episode 4
# 18601         Good                                  Hitman: Episode 4
# 18602         Good                                  Hitman: Episode 4
# 18603         Good                                            Grow Up
# 18604        Great                                      Madden NFL 17
# 18605         Okay                                       No Man's Sky
# 18606         Okay    Starcraft II: Nova Covert Ops -- Mission Pack 2
# 18607         Good                                         Pokemon Go
# 18608     Mediocre                            Carmageddon: Max Damage
# 18609        Great                         Monster Hunter Generations
# 18610         Okay                                   Song of the Deep
# 18611     Mediocre           Tom Clancy's The Division -- Underground
# 18612         Good                                         BoxBoxBoy!
# 18613        Great                           XCOM 2: Shen's Last Gift
# 18614      Amazing                                  Zero Time Dilemma
# 18615      Amazing                                  Zero Time Dilemma
# 18616         Good  Batman: The Telltale Series -- Episode 1: Real...
# 18617        Great                                               Abzu
# 18618      Amazing                                          Starbound
# 18619         Good                                    Human Fall Flat
# 18620         Good                          Tokyo Mirage Sessions #FE
# 18621      Amazing                  LEGO Star Wars: The Force Awakens
# 18622     Mediocre            Star Ocean: Integrity and Faithlessness
# 18623  Masterpiece                                             Inside
# 18624  Masterpiece                                             Inside
#
#                                                      url          platform  \
# 0                 /games/littlebigplanet-vita/vita-98907  PlayStation Vita
# 1      /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita
# 2                              /games/splice/ipad-141070              iPad
# 3                          /games/nhl-13/xbox-360-128182          Xbox 360
# 4                               /games/nhl-13/ps3-128181     PlayStation 3
# 5             /games/total-war-battles-shogun/mac-142565         Macintosh
# 6              /games/double-dragon-neon/xbox-360-131320          Xbox 360
# 7                          /games/guild-wars-2/pc-896298                PC
# 8                   /games/double-dragon-neon/ps3-131321     PlayStation 3
# 9              /games/total-war-battles-shogun/pc-142564                PC
# 10             /games/tekken-tag-tournament-2/ps3-124584     PlayStation 3
# 11        /games/tekken-tag-tournament-2/xbox-360-124581          Xbox 360
# 12                       /games/wild-blood/iphone-139363            iPhone
# 13       /games/mark-of-the-ninja-135615/xbox-360-129276          Xbox 360
# 14             /games/mark-of-the-ninja-135615/pc-143761                PC
# 15     /games/home-a-unique-horror-adventure/mac-2001...         Macintosh
# 16       /games/home-a-unique-horror-adventure/pc-137135                PC
# 17              /games/avengers-initiative/iphone-141579            iPhone
# 18                 /games/way-of-the-samurai-4/ps3-23516     PlayStation 3
# 19        /games/jojos-bizarre-adventure/xbox-360-137717          Xbox 360
# 20             /games/jojos-bizarre-adventure/ps3-137896     PlayStation 3
# 21        /games/mass-effect-3-leviathan/xbox-360-138918          Xbox 360
# 22             /games/mass-effect-3-leviathan/ps3-138915     PlayStation 3
# 23              /games/mass-effect-3-leviathan/pc-138919                PC
# 24     /games/dark-souls-prepare-to-die-edition/pc-13...                PC
# 25                             /games/symphony/pc-136470                PC
# 26                            /games/bastion/ipad-140874              iPad
# 27       /games/tom-clancys-ghost-recon-online/pc-109114                PC
# 28             /games/thirty-flights-of-loving/pc-138374                PC
# 29                           /games/legasista/ps3-127147     PlayStation 3
# ...                                                  ...               ...
# 18595          /games/ghostbusters-the-movie/pc-20052317                PC
# 18596                      /games/necropolis/pc-20030346                PC
# 18597             /games/7-days-to-die/xbox-one-20051934          Xbox One
# 18598                            /games/furi/pc-20044439                PC
# 18599                 /games/pokemon-go/android-20042698           Android
# 18600                /games/hitman-episode-4/pc-20051637                PC
# 18601               /games/hitman-episode-4/ps4-20051638     PlayStation 4
# 18602          /games/hitman-episode-4/xbox-one-20051639          Xbox One
# 18603                         /games/grow-up/pc-20054824                PC
# 18604                /games/madden-nfl-2017/ps4-20052738     PlayStation 4
# 18605                    /games/no-mans-sky/ps4-20009696     PlayStation 4
# 18606  /games/starcraft-ii-nova-covert-ops-mission-pa...                PC
# 18607                  /games/pokemon-go/iphone-20042699            iPhone
# 18608           /games/carmageddon-max-damage/ps4-110143     PlayStation 4
# 18609     /games/monster-hunter-generations/3ds-20037986      Nintendo 3DS
# 18610               /games/song-of-the-deep/ps4-20048663     PlayStation 4
# 18611  /games/tom-clancys-the-division-underground/xb...          Xbox One
# 18612                      /games/boxboxboy/3ds-20055707      Nintendo 3DS
# 18613          /games/xcom-2-shens-last-gift/pc-20055520                PC
# 18614                /games/zero-time-dilemma/3ds-163737      Nintendo 3DS
# 18615             /games/zero-time-dilemma/vita-20039757  PlayStation Vita
# 18616  /games/batman-the-telltale-series-episode-1-re...                PC
# 18617                           /games/abzu/ps4-20019841     PlayStation 4
# 18618                    /games/starbound-2016/pc-128879                PC
# 18619                 /games/human-fall-flat/pc-20051928                PC
# 18620  /games/fire-emblem-x-shin-megami-tensei/wii-u-...             Wii U
# 18621  /games/lego-star-wars-the-force-awakens/ps4-20...     PlayStation 4
# 18622                   /games/star-ocean-5/ps4-20035681     PlayStation 4
# 18623             /games/inside-playdead/xbox-one-121435          Xbox One
# 18624                 /games/inside-playdead/pc-20055740                PC
#
#        score               genre editors_choice  release_year  release_month  \
# 0        9.0          Platformer              Y          2012              9
# 1        9.0          Platformer              Y          2012              9
# 2        8.5              Puzzle              N          2012              9
# 3        8.5              Sports              N          2012              9
# 4        8.5              Sports              N          2012              9
# 5        7.0            Strategy              N          2012              9
# 6        3.0            Fighting              N          2012              9
# 7        9.0                 RPG              Y          2012              9
# 8        3.0            Fighting              N          2012              9
# 9        7.0            Strategy              N          2012              9
# 10       7.5            Fighting              N          2012              9
# 11       7.5            Fighting              N          2012              9
# 12       7.0                 NaN              N          2012              9
# 13       9.0   Action, Adventure              Y          2012              9
# 14       9.0   Action, Adventure              Y          2012              9
# 15       6.5           Adventure              N          2012              9
# 16       6.5           Adventure              N          2012              9
# 17       8.0              Action              N          2012              9
# 18       5.5   Action, Adventure              N          2012              9
# 19       7.0            Fighting              N          2012              9
# 20       7.0            Fighting              N          2012              9
# 21       7.5                 RPG              N          2012              8
# 22       7.5                 RPG              N          2012              8
# 23       7.5                 RPG              N          2012              8
# 24       9.0         Action, RPG              Y          2012              8
# 25       7.0             Shooter              N          2012              8
# 26       9.0         Action, RPG              Y          2012              8
# 27       7.5             Shooter              N          2012              8
# 28       8.0           Adventure              N          2012              8
# 29       6.5         Action, RPG              N          2012              8
# ...      ...                 ...            ...           ...            ...
# 18595    4.4              Action              N          2016              7
# 18596    6.5   Action, Adventure              N          2016              7
# 18597    4.9  Shooter, Adventure              N          2016              7
# 18598    6.8              Action              N          2016              7
# 18599    7.0              Battle              N          2016              7
# 18600    7.4             Shooter              N          2016              8
# 18601    7.4             Shooter              N          2016              8
# 18602    7.4             Shooter              N          2016              8
# 18603    7.8          Platformer              N          2016              8
# 18604    8.6              Sports              N          2016              8
# 18605    6.0           Adventure              N          2016              8
# 18606    6.4            Strategy              N          2016              8
# 18607    7.0              Battle              N          2016              7
# 18608    5.4      Racing, Action              N          2016              7
# 18609    8.0              Action              N          2016              7
# 18610    6.0           Adventure              N          2016              7
# 18611    5.8             Shooter              N          2016              7
# 18612    7.8              Puzzle              N          2016              7
# 18613    8.0            Strategy              N          2016              7
# 18614    9.2           Adventure              Y          2016              6
# 18615    9.2           Adventure              Y          2016              6
# 18616    7.5           Adventure              N          2016              8
# 18617    8.4           Adventure              N          2016              8
# 18618    9.1              Action              Y          2016              7
# 18619    7.9      Puzzle, Action              N          2016              7
# 18620    7.6                 RPG              N          2016              6
# 18621    9.0   Action, Adventure              Y          2016              6
# 18622    5.8                 RPG              N          2016              6
# 18623   10.0           Adventure              Y          2016              6
# 18624   10.0           Adventure              Y          2016              6
#
#        release_day      novi
# 0               12  0.750000
# 1               12  0.750000
# 2               12  0.708333
# 3               11  0.772727
# 4               11  0.772727
# 5               11  0.636364
# 6               11  0.272727
# 7               11  0.818182
# 8               11  0.272727
# 9               11  0.636364
# 10              11  0.681818
# 11              11  0.681818
# 12              10  0.700000
# 13               7  1.285714
# 14               7  1.285714
# 15               6  1.083333
# 16               6  1.083333
# 17               5  1.600000
# 18               3  1.833333
# 19               3  2.333333
# 20               3  2.333333
# 21              31  0.241935
# 22              31  0.241935
# 23              31  0.241935
# 24              31  0.290323
# 25              30  0.233333
# 26              30  0.300000
# 27              29  0.258621
# 28              29  0.275862
# 29              28  0.232143
# ...            ...       ...
# 18595           16  0.275000
# 18596           14  0.464286
# 18597           13  0.376923
# 18598           13  0.523077
# 18599           13  0.538462
# 18600           19  0.389474
# 18601           19  0.389474
# 18602           19  0.389474
# 18603           18  0.433333
# 18604           17  0.505882
# 18605           16  0.375000
# 18606            4  1.600000
# 18607           13  0.538462
# 18608           13  0.415385
# 18609           12  0.666667
# 18610           12  0.500000
# 18611            6  0.966667
# 18612            6  1.300000
# 18613            1  8.000000
# 18614           29  0.317241
# 18615           29  0.317241
# 18616            2  3.750000
# 18617            2  4.200000
# 18618           28  0.325000
# 18619           28  0.282143
# 18620           29  0.262069
# 18621           29  0.310345
# 18622           28  0.207143
# 18623           28  0.357143
# 18624           28  0.357143
#
# [18625 rows x 11 columns]

# %% [markdown]
# #### Boolean indeksiranje

# %% [markdown]
# Pandas nam omogućuje da radimo indeksiranje purem uvjeta kojima je rezultat bool Serija. <Primjerice želimo označiti samo recenzije s ocjenom večom od 7.

# %%
ocjena_filter = recenzije["score"] > 7
ocjena_filter
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10        True
# 11        True
# 12       False
# 13        True
# 14        True
# 15       False
# 16       False
# 17        True
# 18       False
# 19       False
# 20       False
# 21        True
# 22        True
# 23        True
# 24        True
# 25       False
# 26        True
# 27        True
# 28        True
# 29       False
#          ...
# 18595    False
# 18596    False
# 18597    False
# 18598    False
# 18599    False
# 18600     True
# 18601     True
# 18602     True
# 18603     True
# 18604     True
# 18605    False
# 18606    False
# 18607    False
# 18608    False
# 18609     True
# 18610    False
# 18611    False
# 18612     True
# 18613     True
# 18614     True
# 18615     True
# 18616     True
# 18617     True
# 18618     True
# 18619     True
# 18620     True
# 18621     True
# 18622    False
# 18623     True
# 18624     True
# Name: score, Length: 18625, dtype: bool

# %% [markdown]
# U serije *ocjena_filter* sada imamo True/False zapise kada je uvjer zadovoljen odnosno nije. Sad kada imamo *ocjena_filter* možemo napraviti selekciju da uzmemo samo zapise gdje je filter istinit.

# %%
filtrirane_recenzije = recenzije[ocjena_filter]
filtrirane_recenzije.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day  \
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11
#
#        novi
# 0  0.750000
# 1  0.750000
# 2  0.708333
# 3  0.772727
# 4  0.772727

# %% [markdown]
# Naravno možemo i kombinirati uvjete pa primjerice uz ocjenu filtrirati i da bude na platformi Xbox one.

# %%
xbox_one_filter = (recenzije["score"] > 7) & (recenzije["platform"] == "Xbox One")
filtrirane_recenzije = recenzije[xbox_one_filter]
filtrirane_recenzije.head()
# Out:
#       score_phrase                     title  \
# 17137      Amazing                 Gone Home
# 17197      Amazing            Rayman Legends
# 17295      Amazing  LEGO Marvel Super Heroes
# 17313        Great             Dead Rising 3
# 17317        Great           Killer Instinct
#
#                                                      url  platform  score  \
# 17137                 /games/gone-home/xbox-one-20014361  Xbox One    9.5
# 17197            /games/rayman-legends/xbox-one-20008449  Xbox One    9.5
# 17295  /games/lego-marvel-super-heroes/xbox-one-20000826  Xbox One    9.0
# 17313               /games/dead-rising-3/xbox-one-124306  Xbox One    8.3
# 17317      /games/killer-instinct-2013/xbox-one-20000538  Xbox One    8.4
#
#             genre editors_choice  release_year  release_month  release_day  \
# 17137  Simulation              Y          2013              8           15
# 17197  Platformer              Y          2013              8           26
# 17295      Action              Y          2013             10           22
# 17313      Action              N          2013             11           18
# 17317    Fighting              N          2013             11           18
#
#            novi
# 17137  0.633333
# 17197  0.365385
# 17295  0.409091
# 17313  0.461111
# 17317  0.466667

# %% [markdown]
# Kada koristimo više uvjeta važno je da svaki uvjet stavimo u zagrade te između zagrada dodamo znak and (&).

# %% [markdown]
# ### Histogram

# %% [markdown]
# Prvo pozivamo jednu naredbu da nam rezultate iscrtava u Jupyteru

# %%
# %matplotlib inline

# %% [markdown]
# I idemo prikazati histogram za ocjene na Xbox One platformi.

# %%
recenzije[recenzije["platform"] == "Xbox One"]["score"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Idemo sad to usporediti s PlayStation 4 platformom.

# %%
recenzije[recenzije["platform"] == "PlayStation 4"]["score"].plot(kind="hist")

# %% [markdown]
# Iz ovog možemo zaključiti da imamo više dobrih ocjena na PlayStation 4 platformi.

# %% [markdown]
# Naravno histogram možemo napraviti i na već filtriranim podacime (to su zasebni DataFrameovi)

# %%
filtrirane_recenzije["score"].hist()

# %% [markdown]
# Na linku možete skinuti [Data Science Cheat Sheet](https://www.dataquest.io/blog/images/cheat-sheets/pandas-cheat-sheet.pdf)

# %% [markdown]
# ## Zadatak

# %% [markdown]
# Iz DataFramea *recenzije* Napravite novi Dataframe *novi* u kojem će se nalaziti dva stupca. U jednom stupcu Naziv igre, a u drugom stupcu ocjena podjeljena s 2. Filtrirajte samo recenzije za *PlayStation 4* platformu.

# %%
novi = recenzije[recenzije["platform"] == "PlayStation 4"][["title", "score"]].copy()
novi.columns = ["Naziv igre", "ocjena"]
novi["ocjena"] = novi["ocjena"] / 2
novi
# Out:
#                                     Naziv igre  ocjena
# 192                               Sound Shapes    4.50
# 17049                                      Fez    4.75
# 17123                             Rogue Legacy    4.50
# 17140                                Gone Home    4.75
# 17160                              The Swapper    4.65
# ...                                        ...     ...
# 18608                  Carmageddon: Max Damage    2.70
# 18610                         Song of the Deep    3.00
# 18617                                     Abzu    4.20
# 18621        LEGO Star Wars: The Force Awakens    4.50
# 18622  Star Ocean: Integrity and Faithlessness    2.90
#
# [277 rows x 2 columns]

# %%
#bakon što završite pokrenite ovu čeliju
novi.to_csv('novi.csv')

# %% [markdown]
# # Priprema podataka za analizu
# Na ovim vježbama upoznat ćemo se sa sljedećim pojmovima i tehnikama pripreme podataka za analizu:
# - otkrivanje i supstitucija nedostajućih vrijednosti
# - min-max normiranje

# %% [markdown]
# ## Otkrivanje i supstitucija nedostajućih vrijednosti
#
# Postojanje velikog broja nedostajućih vrijednosti uglavnom na prvi pogled asocira na nekvalitetne podatke, ali to
# nužno ne mora uvijek biti istina. Problem je najveći kod atributa koji moraju biti potpuno (100%) popunjeni podacima, a ipak određeni postotak vrijednosti nedostaje. S druge strane, nedostajuće vrijednosti mogu biti korisni putokazi
# kao i ekstremne vrijednosti. Primjerice klijenti koji daju podatke, a imaju smanjeni stupanj lojalnosti potencijalno zbog nezainteresiranosti ili planiranog reduciranja suradnje ili prekida ugovornog odnosa daju manje podataka ako nisu u situaciji da obavezno daju podatak. Praznina u obilježjima je informacija ravnopravna bilo kojoj drugoj informaciji. Problem jedino može nastati ako u podacima postoji visoki postotak neispunjenih vrijednosti atributa do te mjere da ugrožava analizu. Iskustvo pokazuje da je na razini atributa prihvatljiv postotak do dvadeset posto ako govorimo o takvim tipovima informacija.

# %% [markdown]
# ### *Case-Based Reasoning*
#
# Jedan od načina popunjavanja nedostajućih vrijednosti je primjena *Case-Based reasoning* metode, popularno zvane „pitaj svog susjeda“, koja temeljem proračuna sličnosti atributa između slogova, procjenjuje koji je slog najsličniji promatranom slogu kojem nedostaje vrijednost te mu dodaje vrijednost atributa najsličnijeg sloga. Ovdje treba biti oprezan kako bismo izbjegli **multiplikativni aproksimativni efekt** - aproksimaciju nedostajuće vrijednosti pomoću već aproksimirane vrijednosti.
#
# > Općenito: *Case-Based reasoning* je metodologija rješavanja problema na temelju prethodnih iskustava.
#
# > Alternativne tehnike za aproksimaciju nedostajućih vrijednosti podrazumijevaju primjenu naprednijih metoda poput neuronskih mreža i/ili Bayesovih mreža. Općenito ne postoji univerzalno rješenje niti savršena tehnika, već izbor metode i analitičke strategije ovisi o tipu problema koji želimo riješiti, ciljevima analize i ostalim faktorima.

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Vježba: otkrivanje i supstitucija nedostajućih vrijednosti pomoću <i>Case-Based Reasoning</i> metode</b>
# </div>
#
# ### Zadatak
#
# > - Učitajte podatke iz datoteke cars.csv u Pandas DataFrame pod imenom df
# > - Ispišite broj redaka i stupaca u učitanom DataFrameu?
# > - Ispišite sadržaj prvih 5 redaka DataFrame-a na ekran

# %%
# Dopunite program prema uputama
import pandas as pd
import random
import math

df = pd.read_csv('cars.csv', sep=';')

print(df.shape)
df
# Out:
# (957, 14)
#      Car Code Manufacturer   Model           Body  Price       Color  Year  \
# 0           2          bmw   325td          sedan  28699    dark_red  1995
# 1           3          bmw    320i          coupe  33299    dark_red  1995
# 2           4          bmw    540i  station_wagon  87499  dark_green  1997
# 3           5          bmw    520i  station_wagon  43599       black  1996
# 4           6          bmw    316i       fastback  25599    dark_red  1995
# ..        ...          ...     ...            ...    ...         ...   ...
# 952       954          bmw    540i          sedan  54099      silver  1996
# 953       955           vw  passat  station_wagon  25799        gray  1995
# 954       956          bmw  525tds          sedan  38499         red  1996
# 955       957          bmw    316i          sedan  29399      violet  1996
# 956       958           vw  passat  station_wagon  18099      violet  1995
#
#       Miles  Doors  Power       Gas  Speed   CCM  ZIP
# 0     66474      4    115    diesel    203  2500    8
# 1     31802      2    150  gasoline    241  3200    7
# 2      9874      5    285  gasoline    252  4000    1
# 3     32292      5    150  gasoline    183  2000    9
# 4     53714      2    102  gasoline    183  1600    6
# ..      ...    ...    ...       ...    ...   ...  ...
# 952   67534      4    285  gasoline    252  4000    4
# 953   23450      5    100  gasoline    183  1900    8
# 954   53298      4    142    diesel    203  2500    2
# 955   36859      4    102  gasoline    183  1600    2
# 956  101125      5    110    diesel    183  1900    8
#
# [957 rows x 14 columns]

# %% [markdown]
# > - Ispišite broj zapisa s nedostajućim vrijednostima
# > - Obrišite (postavite na None) vrijednost polja **Manufacturer** u 10 slučajno odabranih redaka
# > - Ponovno ispišite broj zapisa s nedostajućim vrijednostima
# > - ispišite sve zapise s nedostajućim vrijednostima

# %%
# Ispišite broj zapisa s nedostajućim vrijednostima
print("Broj zapisa s nedostajućim vrijednostima prije brisanja:")
# df.isnull() - pravi DataFrame gdje je True gdje nedostaju vrijednosti, False gdje su prisutne
# .sum() - sabira True vrijednosti po stupcima (True se računa kao 1, False kao 0)
# .sum() (drugi put) - sabira sve rezultate iz svih stupaca u jedan broj
print(df.isnull().sum().sum())

print("\n" + "="*50 + "\n")

# Obrišite (postavite na None) vrijednost polja Manufacturer u 10 slučajno odabranih redaka
# random.sample() - bira 10 različitih slučajnih indeksa iz raspona 0 do broja redaka u df
# df.loc[] - koristi Named-based indeksiranje (po nazivu reda/stupca)
# df.loc[random_indices, 'Manufacturer'] - odabira retke na random_indices pozicijama, stupac 'Manufacturer'
# = None - postavlja sve te vrijednosti na None (prazno)
random_indices = random.sample(range(len(df)), 10)
print(f"Indeksi redaka gdje briše Manufacturer: {random_indices}")
df.loc[random_indices, 'Manufacturer'] = None

print("\n" + "="*50 + "\n")

# Ponovno ispišite broj zapisa s nedostajućim vrijednostima
print("Broj zapisa s nedostajućim vrijednostima nakon brisanja:")
# Sada bi trebalo biti 10 više od prije jer smo obrisali 10 vrijednosti u Manufacturer stupcu
print(df.isnull().sum().sum())

print("\n" + "="*50 + "\n")

# Ispišite sve zapise s nedostajućim vrijednostima
print("Svi zapisi (redci) s nedostajućim vrijednostima:")
# df.isnull() - True gdje su vrijednosti prazne
# .any(axis=1) - provjerava po redcima (axis=1) - vraća True ako IMA BAR JEDNU praznu vrijednost u redu
# df[...] - filtrira DataFrame i prikazuje samo retke gdje je rezultat True
df[df.isnull().any(axis=1)]
# Out:
# Broj zapisa s nedostajućim vrijednostima prije brisanja:
# 10
#
# ==================================================
#
# Indeksi redaka gdje briše Manufacturer: [688, 664, 768, 418, 685, 102, 486, 584, 539, 665]
#
# ==================================================
#
# Broj zapisa s nedostajućim vrijednostima nakon brisanja:
# 20
#
# ==================================================
#
# Svi zapisi (redci) s nedostajućim vrijednostima:
#     Manufacturer             Model  Doors  numModel
# 29          None      e_290_diesel      5        18
# 61          None             e_280      5         7
# 100         None              golf      5        15
# 102         None             e_280      4         7
# 146         None            passat      4        13
# 152         None             c_280      4        31
# 166         None        a4_1.9_tdi      4         8
# 418         None              316i      4         4
# 486         None              golf      2        15
# 488         None              golf      5        15
# 539         None              540i      4         2
# 584         None              golf      2        15
# 664         None              golf      2        15
# 665         None  c_230_kompressor      4        41
# 681         None              golf      5        15
# 685         None              316i      2         4
# 688         None              323i      4        30
# 765         None            z3_2.8      2        23
# 768         None  c_230_kompressor      5        41
# 836         None              golf      2        15

# %% [markdown]
# U ovom slučaju u kojem nam nedostaje proizvođač automobila u tablici, možemo pretpostaviti da su nam za identifikaciju proizvođača metodom *Case-Based Reasoning* dovoljna polja **Manufacturer**, **Model** i **Doors**.
# Za pronalaženje najbližeg "susjeda" iskoristit ćemo euklidsku distancu koja se računa po formuli<br>
# <img src="Euklidska_distanca.png">
# Budući da polje **Model** nije numerička varijabla, prije računanja euklidske distance potrebno je tekst iz polja pretvoriti u brojčanu šifru
# > - Uklonite sva ostala polja iz DataFramea
# > - dodajte u DataFrame novo polje **numModel** s numeričkom šifrom modela
# > - ispišite prvih 10 redaka DataFramea

# %%
# Uklonite sva ostala polja iz DataFramea
# Zadržavamo samo tri stupca: Manufacturer, Model, Doors
# .copy() je važno jer sprječava upozorenja pri postavljanju novih stupaca
df = df[['Manufacturer', 'Model', 'Doors']].copy()

# Dodajte u DataFrame novo polje numModel s numeričkom šifrom modela
# factorize() pretvara text vrijednosti u brojeve (0, 1, 2, ...)
# [0] uzima samo brojeve, [1] bi bio dictionary za mapiranje
df['numModel'] = pd.factorize(df['Model'])[0]

# Ispišite prvih 10 redaka DataFramea
print("Prvih 10 redaka DataFramea sa numModel:")
df.head(10)
# Out:
# Prvih 10 redaka DataFramea sa numModel:
#     Manufacturer  Model  Doors  numModel
# 0            bmw  325td      4         0
# 1            bmw   320i      2         1
# 2            bmw   540i      5         2
# 3            bmw   520i      5         3
# 4            bmw   316i      2         4
# 5            bmw   523i      5         5
# 6            bmw   318i      2         6
# 7            bmw   318i      4         6
# 8            bmw   318i      4         6
# 9  mercedes-benz  e_280      5         7

# %% [markdown]
# ## Normiranje podataka
# Budući da varijable numModel i Doors koje želimo koristiti za određivanje najmanje distance nisu jednakog reda veličine potrebno ih je normirati. Postoji više načina na koje možemo normirati podatke. Neki od njih su:
# - Min-Max normiranje
# - Z-skaliranje
# - Decimalno skaliranje
#
# ### Min-Max normiranje
#
# Min-max normiranje svodi se na linearnu transformaciju izvornog raspona podataka na novi raspon, najčešće između 0-1.
# <img src="Min-Max.png">
# min’ – nova, normirana minimalna vrijednost<br>
# max’- nova, normirana maksimalna vrijednost<br>
# y’ - nova normirana vrijednost atributa<br>
# min – minimalna vrijednost originalnog niza<br>
# max - maksimalna vrijednost originalnog niza<br>
# y - Izvorna vrijednost atributa
#
# ### Z-skaliranje
#
# Koristimo ga u slučaju u kojem ne znamo minimalnu i maksimalnu vrijednost originalnog niza, a računa se po formuli:
# <img src="Z-skaliranje.png">
#
# ### Decimalno skaliranje
#
# <img src="DecimalnoSkaliranje.png">
#
# U današnjoj vježbi koristit ćemo Min-Max normiranje.
# > - dodajte u DataFrame novo polje **normModel** s Min-Max normiranom vrijednošću šifre modela iz polja **numModel**
# > - dodajte u DataFrame novo polje **normDoors** s Min-Max normiranom vrijednošću šifre modela iz polja **Doors**
# > - ispišite prvih 10 redaka DataFramea

# %%
# Dodajte u DataFrame novo polje normModel s Min-Max normiranom vrijednošću šifre modela
# Min-Max formula: (y - min) / (max - min)
# Onde je y originalna vrijednost, min je minimalna vrijednost u nizu, max je maksimalna
min_model = df['numModel'].min()
max_model = df['numModel'].max()
df['normModel'] = (df['numModel'] - min_model) / (max_model - min_model)

# Dodajte u DataFrame novo polje normDoors s Min-Max normiranom vrijednošću iz polja Doors
min_doors = df['Doors'].min()
max_doors = df['Doors'].max()
df['normDoors'] = (df['Doors'] - min_doors) / (max_doors - min_doors)

# Ispišite prvih 10 redaka DataFramea
print("Prvih 10 redaka DataFramea s normiranim vrijednostima:")
print("\nSvi stupci: Manufacturer, Model, Doors, numModel, normModel, normDoors")
df.head(10)
# Out:
# Prvih 10 redaka DataFramea s normiranim vrijednostima:
#
# Svi stupci: Manufacturer, Model, Doors, numModel, normModel, normDoors
#     Manufacturer  Model  Doors  numModel  normModel  normDoors
# 0            bmw  325td      4         0   0.000000   0.666667
# 1            bmw   320i      2         1   0.022727   0.000000
# 2            bmw   540i      5         2   0.045455   1.000000
# 3            bmw   520i      5         3   0.068182   1.000000
# 4            bmw   316i      2         4   0.090909   0.000000
# 5            bmw   523i      5         5   0.113636   1.000000
# 6            bmw   318i      2         6   0.136364   0.000000
# 7            bmw   318i      4         6   0.136364   0.666667
# 8            bmw   318i      4         6   0.136364   0.666667
# 9  mercedes-benz  e_280      5         7   0.159091   1.000000

# %% [markdown]
# > - ispišite broj redaka DataFramea **df**
# > - Izdvojite retke DataFramea **df** s nedostajućim podacima o proizvođaču u zasebni DataFrame pod nazivom **df_missing**
# > - Izbrišite retke DataFramea **df** s nedostajućim podacima o proizvođaču
# > - ispišite broj redaka DataFramea **df_missing**
# > - ponovno ispišite broj redaka DataFramea **df**
# > - ispišite DataFrame **df_missing**

# %%
# Ispišite broj redaka DataFramea df
print("Broj redaka DataFramea df prije brisanja:")
print(df.shape[0])

print("\n" + "="*50 + "\n")

# Izdvojite retke DataFramea df s nedostajućim podacima o proizvođaču u zasebni DataFrame df_missing
# isnull() vraća True gdje su vrijednosti prazne, pa koristimo .any(axis=1) za provjeravaju po redcima
df_missing = df[df['Manufacturer'].isnull()].copy()

print(f"Broj redaka s nedostajućim Manufacturer podacima: {df_missing.shape[0]}")

print("\n" + "="*50 + "\n")

# Izbrišite retke DataFramea df s nedostajućim podacima o proizvođaču
# Zadržavamo samo redke gdje Manufacturer NIJE null
df = df[df['Manufacturer'].notnull()].copy()

print(f"Broj redaka u df_missing: {df_missing.shape[0]}")
print(f"Novi broj redaka DataFramea df (nakon brisanja): {df.shape[0]}")

print("\n" + "="*50 + "\n")

# Ispišite DataFrame df_missing
print("DataFrame df_missing s nedostajućim vrijednostima:")
df_missing
# Out:
# Broj redaka DataFramea df prije brisanja:
# 957
#
# ==================================================
#
# Broj redaka s nedostajućim Manufacturer podacima: 20
#
# ==================================================
#
# Broj redaka u df_missing: 20
# Novi broj redaka DataFramea df (nakon brisanja): 937
#
# ==================================================
#
# DataFrame df_missing s nedostajućim vrijednostima:
#     Manufacturer             Model  Doors  numModel  normModel  normDoors
# 29          None      e_290_diesel      5        18   0.409091   1.000000
# 61          None             e_280      5         7   0.159091   1.000000
# 100         None              golf      5        15   0.340909   1.000000
# 102         None             e_280      4         7   0.159091   0.666667
# 146         None            passat      4        13   0.295455   0.666667
# 152         None             c_280      4        31   0.704545   0.666667
# 166         None        a4_1.9_tdi      4         8   0.181818   0.666667
# 418         None              316i      4         4   0.090909   0.666667
# 486         None              golf      2        15   0.340909   0.000000
# 488         None              golf      5        15   0.340909   1.000000
# 539         None              540i      4         2   0.045455   0.666667
# 584         None              golf      2        15   0.340909   0.000000
# 664         None              golf      2        15   0.340909   0.000000
# 665         None  c_230_kompressor      4        41   0.931818   0.666667
# 681         None              golf      5        15   0.340909   1.000000
# 685         None              316i      2         4   0.090909   0.000000
# 688         None              323i      4        30   0.681818   0.666667
# 765         None            z3_2.8      2        23   0.522727   0.000000
# 768         None  c_230_kompressor      5        41   0.931818   1.000000
# 836         None              golf      2        15   0.340909   0.000000

# %% [markdown]
# > - Napišite program koji korištenjem formule za izračun euklidske distance pronalazi nedostajuće vrijednosti i zapisuje ih u DataFrame **df_missing** u polje **Manufacturer**
# > - ispišite tablicu **df_missing** u kojoj su nedostajuće vrijednosti supstituirane metodom *Case-Based Reasoninga*.

# %%
# Napišite program koji korištenjem formule za izračun euklidske distance pronalazi nedostajuće vrijednosti
# i zapisuje ih u DataFrame df_missing u polje Manufacturer

# Za svaki redak u df_missing (redci s nedostajućim Manufacturer vrijednostima)
# Trebamo pronaći najbližeg "susjeda" iz df (redci s potpunim podacima)

print("Pronalaženje najbližih susjeda pomoću euklidske distance:")
print("="*60 + "\n")

# Iteriramo kroz sve redke u df_missing
for idx_missing, row_missing in df_missing.iterrows():
    # Euklidska distanca: sqrt((normModel1 - normModel2)^2 + (normDoors1 - normDoors2)^2)
    
    # Vrijednosti iz reda s nedostajućim Manufacturer-om
    model_missing = row_missing['normModel']
    doors_missing = row_missing['normDoors']
    
    # Inicijalizujemo najmanju distancu na beskonačnost i najbližeg susjeda na None
    min_distance = float('inf')
    closest_neighbor_idx = None
    closest_manufacturer = None
    
    # Iteriramo kroz sve redke u df (potpuni redci) da pronađemo najbližeg susjeda
    for idx_complete, row_complete in df.iterrows():
        model_complete = row_complete['normModel']
        doors_complete = row_complete['normDoors']
        
        # Računamo euklidsku distancu
        # Formula: sqrt((x1-x2)^2 + (y1-y2)^2)
        distance = math.sqrt(
            (model_missing - model_complete) ** 2 + 
            (doors_missing - doors_complete) ** 2
        )
        
        # Ako je ovo manja distanca od do sada pronađene, ažuriramo
        if distance < min_distance:
            min_distance = distance
            closest_neighbor_idx = idx_complete
            closest_manufacturer = row_complete['Manufacturer']
    
    # Dodijelujemo pronađenu vrijednost Manufacturer-a redku s nedostajućom vrijednosti
    df_missing.loc[idx_missing, 'Manufacturer'] = closest_manufacturer
    
    print(f"Red {idx_missing}: Model={row_missing['numModel']}, Doors={row_missing['Doors']}")
    print(f"  → Najbliži susjed (Red {closest_neighbor_idx}): Manufacturer={closest_manufacturer}")
    print(f"  → Euklidska distanca: {min_distance:.6f}\n")

print("="*60 + "\n")

# Ispišite tablicu df_missing u kojoj su nedostajuće vrijednosti supstituirane
print("DataFrame df_missing s supstituiranim vrijednostima:")
df_missing
# Out:
# Pronalaženje najbližih susjeda pomoću euklidske distance:
# ============================================================
#
# Red 29: Model=18, Doors=5
#   → Najbliži susjed (Red 487): Manufacturer=mercedes-benz
#   → Euklidska distanca: 0.000000
#
# Red 61: Model=7, Doors=5
#   → Najbliži susjed (Red 9): Manufacturer=mercedes-benz
#   → Euklidska distanca: 0.000000
#
# Red 100: Model=15, Doors=5
#   → Najbliži susjed (Red 38): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 102: Model=7, Doors=4
#   → Najbliži susjed (Red 138): Manufacturer=mercedes-benz
#   → Euklidska distanca: 0.000000
#
# Red 146: Model=13, Doors=4
#   → Najbliži susjed (Red 15): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 152: Model=31, Doors=4
#   → Najbliži susjed (Red 80): Manufacturer=mercedes-benz
#   → Euklidska distanca: 0.000000
#
# Red 166: Model=8, Doors=4
#   → Najbliži susjed (Red 97): Manufacturer=audi
#   → Euklidska distanca: 0.000000
#
# Red 418: Model=4, Doors=4
#   → Najbliži susjed (Red 286): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 146: Model=13, Doors=4
#   → Najbliži susjed (Red 15): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 152: Model=31, Doors=4
#   → Najbliži susjed (Red 80): Manufacturer=mercedes-benz
#   → Euklidska distanca: 0.000000
#
# Red 166: Model=8, Doors=4
#   → Najbliži susjed (Red 97): Manufacturer=audi
#   → Euklidska distanca: 0.000000
#
# Red 418: Model=4, Doors=4
#   → Najbliži susjed (Red 286): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 486: Model=15, Doors=2
#   → Najbliži susjed (Red 17): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 488: Model=15, Doors=5
#   → Najbliži susjed (Red 38): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 539: Model=2, Doors=4
#   → Najbliži susjed (Red 139): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 584: Model=15, Doors=2
#   → Najbliži susjed (Red 17): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 486: Model=15, Doors=2
#   → Najbliži susjed (Red 17): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 488: Model=15, Doors=5
#   → Najbliži susjed (Red 38): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 539: Model=2, Doors=4
#   → Najbliži susjed (Red 139): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 584: Model=15, Doors=2
#   → Najbliži susjed (Red 17): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 664: Model=15, Doors=2
#   → Najbliži susjed (Red 17): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 665: Model=41, Doors=4
#   → Najbliži susjed (Red 257): Manufacturer=mercedes-benz
#   → Euklidska distanca: 0.000000
#
# Red 681: Model=15, Doors=5
#   → Najbliži susjed (Red 38): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 685: Model=4, Doors=2
#   → Najbliži susjed (Red 4): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 688: Model=30, Doors=4
#   → Najbliži susjed (Red 119): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 664: Model=15, Doors=2
#   → Najbliži susjed (Red 17): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 665: Model=41, Doors=4
#   → Najbliži susjed (Red 257): Manufacturer=mercedes-benz
#   → Euklidska distanca: 0.000000
#
# Red 681: Model=15, Doors=5
#   → Najbliži susjed (Red 38): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# Red 685: Model=4, Doors=2
#   → Najbliži susjed (Red 4): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 688: Model=30, Doors=4
#   → Najbliži susjed (Red 119): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 765: Model=23, Doors=2
#   → Najbliži susjed (Red 40): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 768: Model=41, Doors=5
#   → Najbliži susjed (Red 203): Manufacturer=mercedes-benz
#   → Euklidska distanca: 0.000000
#
# Red 836: Model=15, Doors=2
#   → Najbliži susjed (Red 17): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# ============================================================
#
# DataFrame df_missing s supstituiranim vrijednostima:
# Red 765: Model=23, Doors=2
#   → Najbliži susjed (Red 40): Manufacturer=bmw
#   → Euklidska distanca: 0.000000
#
# Red 768: Model=41, Doors=5
#   → Najbliži susjed (Red 203): Manufacturer=mercedes-benz
#   → Euklidska distanca: 0.000000
#
# Red 836: Model=15, Doors=2
#   → Najbliži susjed (Red 17): Manufacturer=vw
#   → Euklidska distanca: 0.000000
#
# ============================================================
#
# DataFrame df_missing s supstituiranim vrijednostima:
#       Manufacturer             Model  Doors  numModel  normModel  normDoors
# 29   mercedes-benz      e_290_diesel      5        18   0.409091   1.000000
# 61   mercedes-benz             e_280      5         7   0.159091   1.000000
# 100             vw              golf      5        15   0.340909   1.000000
# 102  mercedes-benz             e_280      4         7   0.159091   0.666667
# 146             vw            passat      4        13   0.295455   0.666667
# 152  mercedes-benz             c_280      4        31   0.704545   0.666667
# 166           audi        a4_1.9_tdi      4         8   0.181818   0.666667
# 418            bmw              316i      4         4   0.090909   0.666667
# 486             vw              golf      2        15   0.340909   0.000000
# 488             vw              golf      5        15   0.340909   1.000000
# 539            bmw              540i      4         2   0.045455   0.666667
# 584             vw              golf      2        15   0.340909   0.000000
# 664             vw              golf      2        15   0.340909   0.000000
# 665  mercedes-benz  c_230_kompressor      4        41   0.931818   0.666667
# 681             vw              golf      5        15   0.340909   1.000000
# 685            bmw              316i      2         4   0.090909   0.000000
# 688            bmw              323i      4        30   0.681818   0.666667
# 765            bmw            z3_2.8      2        23   0.522727   0.000000
# 768  mercedes-benz  c_230_kompressor      5        41   0.931818   1.000000
# 836             vw              golf      2        15   0.340909   0.000000

# %%
#nakon što završite pokrenite ovu čeliju
df_missing.to_csv('novi2.csv')
